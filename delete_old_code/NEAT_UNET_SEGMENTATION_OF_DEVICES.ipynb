# %%
from skimage.measure import label, regionprops, regionprops_table
from skimage.morphology import binary_dilation
from skimage.transform import rotate
import os
import numpy as np
import matplotlib.pyplot as plt
import pathlib

import numpy as np
import tifffile as tiff
from skimage.transform import resize
import tensorflow as tf
from skimage.draw import ellipse
from skimage import util
from skimage.io import imread
from skimage.color import rgb2hsv, rgb2gray
from skimage.filters import gaussian, threshold_triangle, threshold_otsu, threshold_li, threshold_isodata, threshold_minimum, try_all_threshold, threshold_mean, median
from skimage.exposure import adjust_gamma
from skimage.feature import structure_tensor
from skimage.segmentation import expand_labels, flood, clear_border
from skimage.measure import label,  regionprops_table, find_contours
from skimage.morphology import remove_small_holes, closing, disk, square,opening, remove_small_objects, rectangle, erosion
from skimage import exposure, feature

from skimage.measure import label, regionprops, moments_central
from scipy.ndimage import binary_erosion, rotate, binary_opening, binary_dilation
from scipy.ndimage import distance_transform_edt
from scipy.interpolate import splprep, splev
from skimage.draw import polygon
import tifffile

import tensorflow as tf
from pathlib import Path
import numpy as np
import tifffile as tiff

# %%
from pathlib import Path
import itertools, json, csv, traceback
from typing import Any, Dict
import numpy as np
import tensorflow as tf
import tifffile as tiff

# -----------------------------
# Paths
# -----------------------------
IMG_DIR = Path(r"Z:\Bel\Vascumap_Example_Lifs\labelling\labelled_images\images")
LAB_DIR = Path(r"Z:\Bel\Vascumap_Example_Lifs\labelling\labelled_images\labels")

OUT_DIR = Path(r"Z:\Bel\Vascumap_Example_Lifs\labelling\labelled_images\models_gridsearch")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# -----------------------------
# Base Config
# -----------------------------
PATCH  = 512
BATCH  = 4
EPOCHS = 120

PATCHES_PER_IMAGE_TRAIN = 96
PATCHES_PER_IMAGE_VAL   = 32

AUTOTUNE = tf.data.AUTOTUNE

# -----------------------------
# Random search controls (reduce total runs)
# -----------------------------
N_RUNS = 80          # set ~20–80 for overnight; adjust as you like
SEED = 0
SKIP_IF_ALREADY_DONE = True  # if rerunning, don't repeat completed run_ids

# -----------------------------
# Robust JSON helpers
# -----------------------------
def to_jsonable(x: Any):
    try:
        if isinstance(x, tf.Tensor):
            x = x.numpy()
    except Exception:
        pass

    if isinstance(x, np.generic):
        return x.item()
    if isinstance(x, np.ndarray):
        return x.tolist()
    if isinstance(x, dict):
        return {str(k): to_jsonable(v) for k, v in x.items()}
    if isinstance(x, (list, tuple)):
        return [to_jsonable(v) for v in x]
    if hasattr(x, "__float__"):
        try:
            return float(x)
        except Exception:
            pass
    return x

def safe_json_dump(obj: Any, path: Path, indent: int = 2):
    with open(path, "w") as f:
        json.dump(to_jsonable(obj), f, indent=indent)

# -----------------------------
# Pairing
# -----------------------------
def list_pairs(img_dir: Path, lab_dir: Path, label_suffix="_labels"):
    img_paths = sorted(img_dir.glob("*.tif*"))
    pairs, missing = [], []
    for ip in img_paths:
        candidates = [
            lab_dir / f"{ip.stem}{label_suffix}.tif",
            lab_dir / f"{ip.stem}{label_suffix}.tiff",
            lab_dir / f"{ip.stem}{label_suffix}.TIF",
            lab_dir / f"{ip.stem}{label_suffix}.TIFF",
        ]
        lp = next((c for c in candidates if c.exists()), None)
        if lp is None:
            alt = list(lab_dir.glob(f"{ip.stem}{label_suffix}.tif*"))
            lp = alt[0] if alt else None

        if lp is None:
            missing.append(ip.name)
        else:
            pairs.append((ip, lp))

    if missing:
        print("WARNING: images with no matching label:", missing[:10], ("..." if len(missing) > 10 else ""))
    print(f"Found {len(pairs)} paired image/label files.")
    return pairs

# -----------------------------
# TIFF loading (strict 2D)
# -----------------------------
def load_image(path: Path) -> np.ndarray:
    img = np.squeeze(tiff.imread(str(path)))
    if img.ndim != 2:
        raise ValueError(f"{path.name}: expected 2D image, got {img.shape}")
    return img.astype(np.float32)

def load_mask(path: Path) -> np.ndarray:
    m = np.squeeze(tiff.imread(str(path)))
    if m.ndim != 2:
        raise ValueError(f"{path.name}: expected 2D mask, got {m.shape}")
    return (m > 0).astype(np.uint8)

# -----------------------------
# Patch sampling helpers
# -----------------------------
def compute_boundary(mask: np.ndarray) -> np.ndarray:
    mp = np.pad(mask.astype(np.uint8), 1, mode="edge")
    c = mp[1:-1, 1:-1]
    return (
        (mp[:-2, :-2] != c) | (mp[:-2, 1:-1] != c) | (mp[:-2, 2:] != c) |
        (mp[1:-1, :-2] != c) |                        (mp[1:-1, 2:] != c) |
        (mp[2:, :-2] != c)  | (mp[2:, 1:-1] != c)  | (mp[2:, 2:] != c)
    )

def sample_patch(img: np.ndarray, mask: np.ndarray, patch: int,
                 p_boundary: float, p_background: float, p_interior: float):
    H, W = img.shape
    ph = pw = patch

    boundary = compute_boundary(mask)
    bg = mask == 0
    interior = (mask == 1) & (~boundary)

    r = np.random.rand()
    if r < p_boundary and boundary.any():
        ys, xs = np.where(boundary)
    elif r < p_boundary + p_background and bg.any():
        ys, xs = np.where(bg)
    else:
        if interior.any():
            ys, xs = np.where(interior)
        elif (mask == 1).any():
            ys, xs = np.where(mask == 1)
        else:
            ys, xs = np.array([H // 2]), np.array([W // 2])

    i = np.random.randint(len(ys))
    cy, cx = int(ys[i]), int(xs[i])

    y0 = cy - ph // 2
    x0 = cx - pw // 2
    y1 = y0 + ph
    x1 = x0 + pw

    y0c = max(0, y0)
    x0c = max(0, x0)
    y1c = min(H, y1)
    x1c = min(W, x1)

    img_p = img[y0c:y1c, x0c:x1c]
    msk_p = mask[y0c:y1c, x0c:x1c]

    pad_top = y0c - y0
    pad_left = x0c - x0
    pad_bottom = y1 - y1c
    pad_right = x1 - x1c

    if pad_top or pad_left or pad_bottom or pad_right:
        img_p = np.pad(img_p, ((pad_top, pad_bottom), (pad_left, pad_right)), mode="reflect")
        msk_p = np.pad(msk_p, ((pad_top, pad_bottom), (pad_left, pad_right)), mode="constant", constant_values=0)

    if img_p.shape != (ph, pw) or msk_p.shape != (ph, pw):
        raise ValueError(f"Bad patch shape img={img_p.shape}, msk={msk_p.shape}, from image {img.shape}")

    return img_p.astype(np.float32), msk_p.astype(np.uint8)

# -----------------------------
# Normalization + augmentation
# -----------------------------
def fast_normalize(img):
    img = tf.cast(img, tf.float32)
    mean = tf.reduce_mean(img)
    std = tf.math.reduce_std(img)
    img = (img - mean) / tf.maximum(std, 1e-6)
    img = tf.clip_by_value(img, -3.0, 3.0)
    return (img + 3.0) / 6.0

def augment(img, msk):
    if tf.random.uniform([]) < 0.5:
        img = tf.image.flip_left_right(img)
        msk = tf.image.flip_left_right(msk)
    if tf.random.uniform([]) < 0.5:
        img = tf.image.flip_up_down(img)
        msk = tf.image.flip_up_down(msk)

    k = tf.random.uniform([], 0, 4, tf.int32)
    img = tf.image.rot90(img, k)
    msk = tf.image.rot90(msk, k)

    img = tf.image.random_brightness(img, 0.15)
    img = tf.image.random_contrast(img, 0.7, 1.3)

    gamma = tf.random.uniform([], 0.7, 1.6)
    img = tf.pow(tf.clip_by_value(img, 0.0, 1.0), gamma)

    noise = tf.random.normal(tf.shape(img), stddev=0.03)
    img = tf.clip_by_value(img + noise, 0.0, 1.0)
    return img, msk

# -----------------------------
# Morph ops + weight maps
# -----------------------------
def _dilate(x, r):
    k = 2 * r + 1
    x4 = tf.expand_dims(x, 0)
    y = tf.nn.max_pool2d(x4, ksize=k, strides=1, padding="SAME")
    return tf.squeeze(y, 0)

def _erode(x, r):
    return 1.0 - _dilate(1.0 - x, r)

def boundary_band(mask01, r):
    d = _dilate(mask01, r)
    e = _erode(mask01, r)
    band = tf.clip_by_value(d - e, 0.0, 1.0)
    return tf.cast(band > 0.0, tf.float32)

def make_weight_map(mask01, band_radius, boundary_weight, bg_weight):
    band = boundary_band(mask01, r=band_radius)
    bg = 1.0 - mask01
    return 1.0 + (boundary_weight - 1.0) * band + (bg_weight - 1.0) * bg

# -----------------------------
# Dataset
# -----------------------------
def make_dataset(pairs, patches_per_image, training,
                 p_boundary, p_background, p_interior,
                 band_radius, boundary_weight, bg_weight):
    def gen():
        for ip, lp in pairs:
            img = load_image(ip)
            msk = load_mask(lp)
            for _ in range(patches_per_image):
                yield sample_patch(img, msk, PATCH, p_boundary, p_background, p_interior)

    ds = tf.data.Dataset.from_generator(
        gen,
        output_signature=(
            tf.TensorSpec((PATCH, PATCH), tf.float32),
            tf.TensorSpec((PATCH, PATCH), tf.uint8),
        )
    )

    def prep(img, msk):
        img = tf.expand_dims(img, -1)
        msk = tf.expand_dims(tf.cast(msk, tf.float32), -1)

        img = tf.ensure_shape(img, (PATCH, PATCH, 1))
        msk = tf.ensure_shape(msk, (PATCH, PATCH, 1))

        img = fast_normalize(img)
        if training:
            img, msk = augment(img, msk)

        w = make_weight_map(msk, band_radius, boundary_weight, bg_weight)
        y = tf.concat([msk, w], axis=-1)  # [PATCH, PATCH, 2] => (mask, weight)
        y = tf.ensure_shape(y, (PATCH, PATCH, 2))
        return img, y

    if training:
        ds = ds.shuffle(2048)
    ds = ds.map(prep, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH).prefetch(AUTOTUNE)
    return ds

# -----------------------------
# U-Net
# -----------------------------
def conv_block(x, f):
    x = tf.keras.layers.Conv2D(f, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(f, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x

def build_unet(dropout=0.3, base_filters=32):
    inputs = tf.keras.Input((PATCH, PATCH, 1))
    c1 = conv_block(inputs, base_filters)
    p1 = tf.keras.layers.MaxPool2D()(c1)
    c2 = conv_block(p1, base_filters*2)
    p2 = tf.keras.layers.MaxPool2D()(c2)
    c3 = conv_block(p2, base_filters*4)
    p3 = tf.keras.layers.MaxPool2D()(c3)
    c4 = conv_block(p3, base_filters*8)
    p4 = tf.keras.layers.MaxPool2D()(c4)

    bn = conv_block(p4, base_filters*16)
    bn = tf.keras.layers.Dropout(dropout)(bn)

    u4 = tf.keras.layers.UpSampling2D()(bn)
    u4 = tf.keras.layers.Concatenate()([u4, c4])
    u4 = conv_block(u4, base_filters*8)

    u3 = tf.keras.layers.UpSampling2D()(u4)
    u3 = tf.keras.layers.Concatenate()([u3, c3])
    u3 = conv_block(u3, base_filters*4)

    u2 = tf.keras.layers.UpSampling2D()(u3)
    u2 = tf.keras.layers.Concatenate()([u2, c2])
    u2 = conv_block(u2, base_filters*2)

    u1 = tf.keras.layers.UpSampling2D()(u2)
    u1 = tf.keras.layers.Concatenate()([u1, c1])
    u1 = conv_block(u1, base_filters)

    out = tf.keras.layers.Conv2D(1, 1, activation="sigmoid")(u1)
    return tf.keras.Model(inputs, out)

# -----------------------------
# Loss / metric
# -----------------------------
def dice_coef(y_true_packed, y_pred, eps=1e-6):
    y_true = tf.cast(y_true_packed[..., 0:1], tf.float32)
    y_pred = tf.clip_by_value(tf.cast(y_pred, tf.float32), 0.0, 1.0)
    num = 2.0 * tf.reduce_sum(y_true * y_pred) + eps
    den = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + eps
    return num / den

def dice_loss(y_true_packed, y_pred):
    return 1.0 - dice_coef(y_true_packed, y_pred)

def weighted_bce_dice_loss(y_true_packed, y_pred):
    y_true = tf.cast(y_true_packed[..., 0:1], tf.float32)
    w      = tf.cast(y_true_packed[..., 1:2], tf.float32)

    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)  # [B,H,W]
    bce = tf.expand_dims(bce, axis=-1)                         # [B,H,W,1]

    wbce = tf.reduce_sum(bce * w) / tf.maximum(tf.reduce_sum(w), 1e-6)
    return wbce + dice_loss(y_true_packed, y_pred)

# -----------------------------
# Split once (fair comparison)
# -----------------------------
pairs = list_pairs(IMG_DIR, LAB_DIR, label_suffix="_labels")
rng = np.random.default_rng(SEED)

idx = np.arange(len(pairs))
rng.shuffle(idx)

n_val = max(6, int(0.2 * len(pairs)))
val_pairs = [pairs[i] for i in idx[:n_val]]
train_pairs = [pairs[i] for i in idx[n_val:]]

print(f"Train images: {len(train_pairs)} | Val images: {len(val_pairs)}")

# -----------------------------
# OPTION A: grid WITHOUT p_interior (computed)
# Also reduce search size via random sampling of combinations.
# -----------------------------
grid = {
    "lr":             [3e-4, 1e-4],
    "boundary_weight":[4.0, 6.0, 8.0],
    "bg_weight":      [1.0, 1.2, 1.5],
    "band_radius":    [2, 3, 4],
    "p_boundary":     [0.55, 0.65],
    "p_background":   [0.20],
    "dropout":        [0.2, 0.3],
}

def compute_p_interior(p_boundary: float, p_background: float) -> float:
    p_interior = 1.0 - float(p_boundary) - float(p_background)
    if p_interior < 0:
        raise ValueError(f"Negative p_interior={p_interior} from p_boundary={p_boundary}, p_background={p_background}")
    return p_interior

# Build full cartesian list of combos then sample N_RUNS without replacement
keys = list(grid.keys())
vals = [grid[k] for k in keys]
all_combos = [dict(zip(keys, c)) for c in itertools.product(*vals)]
total_all = len(all_combos)
print(f"Total possible combos: {total_all}")

if N_RUNS > total_all:
    N_RUNS = total_all

chosen_idx = rng.choice(np.arange(total_all), size=N_RUNS, replace=False)
chosen_params_list = [all_combos[i] for i in chosen_idx]
print(f"Random search runs: {len(chosen_params_list)} (seed={SEED})")

# Summary CSV
summary_path = OUT_DIR / "grid_results.csv"
if not summary_path.exists():
    with open(summary_path, "w", newline="") as f:
        w = csv.writer(f)
        w.writerow([
            "run_id",
            "status",
            "error",
            "best_val_dice",
            "best_epoch",
            "final_val_dice",
            "final_epoch",
            "lr","boundary_weight","bg_weight","band_radius",
            "p_boundary","p_background","p_interior","dropout"
        ])

def make_run_id(i: int, p: Dict[str, Any]) -> str:
    # Include p_interior in the ID so it's fully specified
    pi = compute_p_interior(p["p_boundary"], p["p_background"])
    rid = f"run{i:03d}_" + "_".join([
        f"lr{p['lr']:.0e}",
        f"bw{p['boundary_weight']}",
        f"bg{p['bg_weight']}",
        f"br{p['band_radius']}",
        f"pB{p['p_boundary']}",
        f"pBG{p['p_background']}",
        f"pI{pi}",
        f"do{p['dropout']}",
    ]).replace(".", "p")
    return rid

# If rerunning, optionally skip runs that already wrote a "best" model
existing_best = set()
if SKIP_IF_ALREADY_DONE:
    for pth in OUT_DIR.glob("*_best.keras"):
        existing_best.add(pth.name.replace("_best.keras", ""))

# -----------------------------
# Run loop (random search)
# -----------------------------
for run_counter, params in enumerate(chosen_params_list, start=1):
    # Option A: compute p_interior always
    params = dict(params)  # copy
    params["p_interior"] = compute_p_interior(params["p_boundary"], params["p_background"])

    run_id = make_run_id(run_counter, params)

    if SKIP_IF_ALREADY_DONE and run_id in existing_best:
        print(f"Skipping (already has best model): {run_id}")
        continue

    print("\n" + "="*80)
    print(f"[{run_counter}/{len(chosen_params_list)}] {run_id}")
    print(params)

    status = "ok"
    err_msg = ""
    best_val_dice = float("nan")
    best_epoch = -1
    final_val_dice = float("nan")
    final_epoch = -1

    try:
        tf.keras.backend.clear_session()
        tf.random.set_seed(SEED)
        np.random.seed(SEED)

        train_ds = make_dataset(
            train_pairs, PATCHES_PER_IMAGE_TRAIN, training=True,
            p_boundary=params["p_boundary"],
            p_background=params["p_background"],
            p_interior=params["p_interior"],
            band_radius=params["band_radius"],
            boundary_weight=params["boundary_weight"],
            bg_weight=params["bg_weight"],
        )
        val_ds = make_dataset(
            val_pairs, PATCHES_PER_IMAGE_VAL, training=False,
            p_boundary=params["p_boundary"],
            p_background=params["p_background"],
            p_interior=params["p_interior"],
            band_radius=params["band_radius"],
            boundary_weight=params["boundary_weight"],
            bg_weight=params["bg_weight"],
        )

        model = build_unet(dropout=params["dropout"], base_filters=32)
        model.compile(
            optimizer=tf.keras.optimizers.Adam(params["lr"]),
            loss=weighted_bce_dice_loss,
            metrics=[dice_coef],
        )

        best_path  = OUT_DIR / f"{run_id}_best.keras"
        final_path = OUT_DIR / f"{run_id}_final.keras"
        hist_path  = OUT_DIR / f"{run_id}_history.json"

        callbacks = [
            tf.keras.callbacks.TerminateOnNaN(),
            tf.keras.callbacks.ModelCheckpoint(
                filepath=str(best_path),
                monitor="val_dice_coef",
                mode="max",
                save_best_only=True,
                verbose=1,
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor="val_loss", factor=0.5, patience=8, min_lr=1e-6, verbose=1
            ),
            tf.keras.callbacks.EarlyStopping(
                monitor="val_dice_coef", mode="max", patience=20, restore_best_weights=False, verbose=1
            ),
            tf.keras.callbacks.CSVLogger(str(OUT_DIR / f"{run_id}_log.csv")),
        ]

        history = model.fit(
            train_ds,
            validation_data=val_ds,
            epochs=EPOCHS,
            callbacks=callbacks,
            verbose=1,
        )

        # Save final epoch model explicitly (comment this out if you only want best)
        model.save(str(final_path))

        # Save history robustly
        safe_json_dump(history.history, hist_path, indent=2)

        # Summary stats
        val_dice_hist = history.history.get("val_dice_coef", [])
        val_dice_hist = [float(v) for v in to_jsonable(val_dice_hist)]
        if val_dice_hist:
            best_val_dice = float(np.max(val_dice_hist))
            best_epoch = int(np.argmax(val_dice_hist) + 1)
            final_val_dice = float(val_dice_hist[-1])
            final_epoch = int(len(val_dice_hist))

        print(f"Saved best:   {best_path.name}")
        print(f"Saved final:  {final_path.name}")
        print(f"Saved hist:   {hist_path.name}")
        print(f"Best val dice: {best_val_dice:.4f} (epoch {best_epoch}); final val dice: {final_val_dice:.4f}")

    except Exception as e:
        status = "failed"
        err_msg = f"{type(e).__name__}: {e}"
        tb = traceback.format_exc()

        crash_path = OUT_DIR / f"{run_id}_ERROR.txt"
        with open(crash_path, "w") as f:
            f.write(err_msg + "\n\n")
            f.write(tb)

        # Optional: try to save a crash checkpoint
        try:
            if "model" in locals():
                crash_model_path = OUT_DIR / f"{run_id}_crash.keras"
                model.save(str(crash_model_path))
        except Exception:
            pass

        print(f"RUN FAILED: {run_id} -> {err_msg}")

    finally:
        with open(summary_path, "a", newline="") as f:
            w = csv.writer(f)
            w.writerow([
                run_id,
                status,
                err_msg,
                best_val_dice,
                best_epoch,
                final_val_dice,
                final_epoch,
                params["lr"], params["boundary_weight"], params["bg_weight"], params["band_radius"],
                params["p_boundary"], params["p_background"], params["p_interior"], params["dropout"]
            ])
# Out:
# Found 73 paired image/label files.
# Train images: 59 | Val images: 14
# Total possible combos: 216
# Random search runs: 80 (seed=0)
#
# ================================================================================
# [1/80] run001_lr1e-04_bw8p0_bg1p0_br2_pB0p65_pBG0p2_pI0p14999999999999997_do0p3
# {'lr': 0.0001, 'boundary_weight': 8.0, 'bg_weight': 1.0, 'band_radius': 2, 'p_boundary': 0.65, 'p_background': 0.2, 'dropout': 0.3, 'p_interior': 0.14999999999999997}
# Epoch 1/120
#    1416/Unknown - 190s 102ms/step - loss: 0.7739 - dice_coef: 0.7124
# Epoch 1: val_dice_coef improved from -inf to 0.27134, saving model to Z:\Bel\Vascumap_Example_Lifs\labelling\labelled_images\models_gridsearch\run001_lr1e-04_bw8p0_bg1p0_br2_pB0p65_pBG0p2_pI0p14999999999999997_do0p3_best.keras
# 1416/1416 [==============================] - 202s 111ms/step - loss: 0.7739 - dice_coef: 0.7124 - val_loss: 1.7699 - val_dice_coef: 0.2713 - lr: 1.0000e-04
# Epoch 2/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.6452 - dice_coef: 0.7657
# Epoch 2: val_dice_coef improved from 0.27134 to 0.67401, saving model to Z:\Bel\Vascumap_Example_Lifs\labelling\labelled_images\models_gridsearch\run001_lr1e-04_bw8p0_bg1p0_br2_pB0p65_pBG0p2_pI0p14999999999999997_do0p3_best.keras
# 1416/1416 [==============================] - 201s 111ms/step - loss: 0.6452 - dice_coef: 0.7657 - val_loss: 0.8024 - val_dice_coef: 0.6740 - lr: 1.0000e-04
# Epoch 3/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.6043 - dice_coef: 0.7801
# Epoch 3: val_dice_coef did not improve from 0.67401
# 1416/1416 [==============================] - 206s 112ms/step - loss: 0.6043 - dice_coef: 0.7801 - val_loss: 1.3384 - val_dice_coef: 0.5119 - lr: 1.0000e-04
# Epoch 4/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.5704 - dice_coef: 0.7935
# Epoch 4: val_dice_coef did not improve from 0.67401
# 1416/1416 [==============================] - 205s 111ms/step - loss: 0.5704 - dice_coef: 0.7935 - val_loss: 0.7842 - val_dice_coef: 0.6628 - lr: 1.0000e-04
# Epoch 5/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.5528 - dice_coef: 0.8004
# Epoch 5: val_dice_coef did not improve from 0.67401
# 1416/1416 [==============================] - 209s 113ms/step - loss: 0.5528 - dice_coef: 0.8004 - val_loss: 0.9734 - val_dice_coef: 0.6101 - lr: 1.0000e-04
# Epoch 6/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.5268 - dice_coef: 0.8090
# Epoch 6: val_dice_coef did not improve from 0.67401
# 1416/1416 [==============================] - 207s 113ms/step - loss: 0.5268 - dice_coef: 0.8090 - val_loss: 0.8997 - val_dice_coef: 0.6528 - lr: 1.0000e-04
# Epoch 7/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.5086 - dice_coef: 0.8174
# Epoch 7: val_dice_coef improved from 0.67401 to 0.70215, saving model to Z:\Bel\Vascumap_Example_Lifs\labelling\labelled_images\models_gridsearch\run001_lr1e-04_bw8p0_bg1p0_br2_pB0p65_pBG0p2_pI0p14999999999999997_do0p3_best.keras
# 1416/1416 [==============================] - 211s 114ms/step - loss: 0.5086 - dice_coef: 0.8174 - val_loss: 0.7168 - val_dice_coef: 0.7022 - lr: 1.0000e-04
# Epoch 8/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.4901 - dice_coef: 0.8254
# Epoch 8: val_dice_coef did not improve from 0.70215
# 1416/1416 [==============================] - 210s 117ms/step - loss: 0.4901 - dice_coef: 0.8254 - val_loss: 1.5579 - val_dice_coef: 0.4462 - lr: 1.0000e-04
# Epoch 9/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.4853 - dice_coef: 0.8267
# Epoch 9: val_dice_coef did not improve from 0.70215
# 1416/1416 [==============================] - 221s 119ms/step - loss: 0.4853 - dice_coef: 0.8267 - val_loss: 1.1634 - val_dice_coef: 0.5510 - lr: 1.0000e-04
# Epoch 10/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.4836 - dice_coef: 0.8270
# Epoch 10: val_dice_coef did not improve from 0.70215
# 1416/1416 [==============================] - 203s 113ms/step - loss: 0.4836 - dice_coef: 0.8270 - val_loss: 1.4591 - val_dice_coef: 0.4533 - lr: 1.0000e-04
# Epoch 11/120
# 1416/1416 [==============================] - ETA: 0s - loss: 0.4694 - dice_coef: 0.8327
# Epoch 11: val_dice_coef did not improve from 0.70215
# 1416/1416 [==============================] - 207s 115ms/step - loss: 0.4694 - dice_coef: 0.8327 - val_loss: 1.3702 - val_dice_coef: 0.4710 - lr: 1.0000e-04
# Epoch 12/120
# 1124/1416 [======================>.......] - ETA: 1:08 - loss: 0.4410 - dice_coef: 0.8439

# %%
TARGET_H, TARGET_W = 512, 512
DS = 4

# load model
model = tf.keras.models.load_model("device_unet_boundaryweighted_final2.keras", compile=False)

unseen_image_folder = Path(r"Z:\Bel\Vascumap_Example_Lifs\max_projections\unseen_images")
tif_files = list(unseen_image_folder.glob("*.tif"))
i=7
img_path = tif_files[i]
print(img_path)
img_full = tiff.imread(tif_files[i])
# downsample x4 (same as your dataset)
h, w = img_full.shape
h_ds, w_ds = h // DS, w // DS

img_ds = resize(
    img_full, (h_ds, w_ds),
    order=1, preserve_range=True, anti_aliasing=True
).astype(np.float32)

# normalize (same style as training)
p1, p99 = np.percentile(img_ds, [1, 99])
img_ds = np.clip((img_ds - p1) / (p99 - p1 + 1e-6), 0, 1)

# IMPORTANT: resize to model input size
img_in = resize(
    img_ds, (TARGET_H, TARGET_W),
    order=1, preserve_range=True, anti_aliasing=True
).astype(np.float32)

x = img_in[None, ..., None]  # (1, 512, 512, 1)

# predict
pred_in = model.predict(x)[0, ..., 0]  # (512, 512) probabilities
print("pred_in min/max/mean:", float(pred_in.min()), float(pred_in.max()), float(pred_in.mean()))

# resize prediction back to downsampled size
pred_ds = resize(
    pred_in, (h_ds, w_ds),
    order=1, preserve_range=True, anti_aliasing=True
).astype(np.float32)
print("pred_in min/max/mean:", float(pred_in.min()), float(pred_in.max()), float(pred_in.mean()))


mask_ds = (pred_ds > 0.3).astype(np.uint8)
plt.imshow(mask_ds, cmap='gray')
# Out:
# Z:\Bel\Vascumap_Example_Lifs\max_projections\unseen_images\20250619_vascumap_dev25_11_img6_maxproj.ome.tif
# 1/1 [==============================] - 0s 254ms/step
# pred_in min/max/mean: 0.0063470639288425446 0.9693641662597656 0.4045558571815491
# pred_in min/max/mean: 0.0063470639288425446 0.9693641662597656 0.4045558571815491

# %%
# upsample mask back to full-res (nearest!)
mask_full = resize(
    mask_ds, (h, w),
    order=0, preserve_range=True, anti_aliasing=False
).astype(np.uint8)
clean_mask = remove_small_objects(mask_full.astype(bool), min_size=20000)
clean_mask = remove_small_holes(clean_mask, area_threshold=20000)
# clean_mask = closing(clean_mask, square(100))
# save
# out_path = img_path.with_name(img_path.stem + "_pred_mask.tif")
# tiff.imwrite(out_path, mask_full)
# print("Saved:", out_path)
labelled_device = label(clean_mask)
fig, ax = plt.subplots(1,4, figsize=(15,5))
ax[0].imshow(img_full, cmap='gray')
# ax[1].imshow(mask_full, cmap='gray')
# ax[2].imshow(clean_mask, cmap="gray")
# ax[3].imshow(img_full, cmap='gray')
# ax[3].imshow(np.ma.masked_where(labelled_device == 0, labelled_device), cmap="jet", alpha=0.5, interpolation="none")

# %%
import numpy as np
from scipy.ndimage import distance_transform_edt
from skimage.measure import moments_central
from skimage.transform import rotate

# -----------------------------
# Helpers
# -----------------------------
def _moving_average(x: np.ndarray, win: int) -> np.ndarray:
    if win is None or win <= 1:
        return x
    if win % 2 == 0:
        win += 1
    k = np.ones(win, dtype=np.float32) / win
    return np.convolve(x.astype(np.float32), k, mode="same")

def _largest_true_run(b: np.ndarray):
    """Return (start, end) inclusive for the largest contiguous True run in 1D bool array."""
    idx = np.flatnonzero(b)
    if idx.size == 0:
        return None
    splits = np.where(np.diff(idx) > 1)[0] + 1
    runs = np.split(idx, splits)
    best = max(runs, key=len)
    return int(best[0]), int(best[-1])

def _pad_to_avoid_crop(arr: np.ndarray, pad_extra: int = 10):
    """Pad enough so rotation won't crop, return padded array and (pad_y, pad_x)."""
    h, w = arr.shape
    diag = int(np.ceil(np.sqrt(h*h + w*w)))
    pad_y = max(0, (diag - h) // 2) + pad_extra
    pad_x = max(0, (diag - w) // 2) + pad_extra
    arr_p = np.pad(arr, ((pad_y, pad_y), (pad_x, pad_x)), mode="constant", constant_values=0)
    return arr_p, pad_y, pad_x

def _unpad(arr: np.ndarray, pad_y: int, pad_x: int, out_h: int, out_w: int):
    return arr[pad_y:pad_y+out_h, pad_x:pad_x+out_w]

def _orientation_from_moments(mask_bool: np.ndarray, core_quantile: float = 0.6) -> float:
    """
    Compute orientation (deg) of the major axis using 2nd central moments,
    but on a 'core' to reduce influence of inlets / missing corners.
    Returns angle in degrees (CCW from +x axis).
    """
    m = mask_bool.astype(bool)
    if m.sum() < 100:
        raise ValueError("Mask too small/empty.")

    # Core: keep pixels far from boundary (inlets have low distance)
    dt = distance_transform_edt(m)
    thr = np.quantile(dt[m], core_quantile)
    core = m & (dt >= thr)
    if core.sum() < 1000:
        core = m

    img = core.astype(float)
    mu = moments_central(img)

    y20 = mu[2, 0]
    y02 = mu[0, 2]
    y11 = mu[1, 1]

    angle_rad = 0.5 * np.arctan2(2.0 * y11, (y20 - y02))
    angle_deg = float(np.rad2deg(angle_rad))
    return angle_deg

# -----------------------------
# Main: rotation + central rectangle
# -----------------------------
def find_central_rectangle(mask,
                           core_quantile: float = 0.6,
                           frac: float = 0.6,
                           smooth: int = 151,
                           pad_extra: int = 10):
    """
    mask: 2D bool or {0,1}. Device is True/1.
    Returns:
      angle_deg: estimated orientation of device (deg CCW from +x)
      rect_mask: boolean rectangle mask in ORIGINAL image coordinates
      bbox: (ymin, ymax, xmin, xmax) in ORIGINAL coords
      rect_mask_rot: rectangle mask in ROTATED+PADDED coords
      bbox_rot: (ymin, ymax, xmin, xmax) in ROTATED+PADDED coords
      mask_rot: rotated+pad mask (for debugging/visualisation)
    """
    m = mask.astype(bool)
    H, W = m.shape

    # 1) orientation (moments on a core)
    angle_deg = _orientation_from_moments(m, core_quantile=core_quantile)

    # 2) pad to avoid cropping when rotating
    m_pad, py, px = _pad_to_avoid_crop(m.astype(np.uint8), pad_extra=pad_extra)

    # 3) rotate so the long axis aligns vertically
    # moments angle is wrt +x axis; align major axis with vertical => rotate by (90 - angle)
    rot_deg = 90.0 - angle_deg
    mask_rot = rotate(
        m_pad.astype(np.float32),
        rot_deg,
        resize=False,          # keep padded shape
        order=0,               # nearest
        preserve_range=True,
        mode="constant",
        cval=0.0
    ) > 0.5

    # 4) projection-based bbox in rotated frame (fast)
    row = mask_rot.sum(axis=1).astype(np.float32)
    col = mask_rot.sum(axis=0).astype(np.float32)

    row_s = _moving_average(row, smooth)
    col_s = _moving_average(col, smooth)

    row_keep = row_s >= (frac * row_s.max())
    col_keep = col_s >= (frac * col_s.max())

    yr = _largest_true_run(row_keep)
    xr = _largest_true_run(col_keep)
    if yr is None or xr is None:
        raise ValueError("Could not find rectangle in rotated mask. Try lowering frac or increasing smooth/core_quantile.")

    ymin_r, ymax_r = yr
    xmin_r, xmax_r = xr

    rect_mask_rot = np.zeros_like(mask_rot, dtype=bool)
    rect_mask_rot[ymin_r:ymax_r+1, xmin_r:xmax_r+1] = True
    bbox_rot = (ymin_r, ymax_r, xmin_r, xmax_r)

    # 5) rotate rectangle mask back to padded original orientation
    rect_back_pad = rotate(
        rect_mask_rot.astype(np.float32),
        -rot_deg,
        resize=False,
        order=0,
        preserve_range=True,
        mode="constant",
        cval=0.0
    ) > 0.5

    # 6) unpad back to original image size
    rect_mask = _unpad(rect_back_pad, py, px, H, W)

    # 7) bbox in original coords (tight bbox of returned rect)
    ys, xs = np.where(rect_mask)
    if ys.size == 0:
        raise ValueError("Recovered rectangle is empty after inverse rotation/unpadding.")
    ymin, ymax = int(ys.min()), int(ys.max())
    xmin, xmax = int(xs.min()), int(xs.max())
    bbox = (ymin, ymax, xmin, xmax)

    return angle_deg, rect_mask, bbox, rect_mask_rot, bbox_rot, mask_rot


# -----------------------------
# Example usage
# -----------------------------

angle_deg, rect_mask, bbox, rect_rot, bbox_rot, mask_rot = find_central_rectangle(
    clean_mask,
    core_quantile=0.6,  # raise to 0.7–0.8 if inlets bias angle
    frac=0.6,           # lower to include more; raise to exclude inlets
    smooth=151,         # increase if inlet bumps distort projections
    pad_extra=10
)

print("Estimated angle (deg):", angle_deg)
print("Rectangle bbox (orig):", bbox)
# Out:
# Estimated angle (deg): 0.9125984553183327
# Rectangle bbox (orig): (434, 2575, 2986, 3425)

# %%
fig, ax = plt.subplots(1,4, figsize=(15,5))
ax[0].imshow(img_full, cmap='gray')
ax[1].imshow(mask_full, cmap='gray')
ax[2].imshow(img_full, cmap='gray')
ax[2].imshow(np.ma.masked_where(clean_mask == 0, clean_mask), cmap="gray")
ax[3].imshow(img_full, cmap='gray')
ax[3].imshow(np.ma.masked_where(rect_mask == 0, rect_mask), cmap="jet", alpha=0.5, interpolation="none")
