# %%
import napari
import numpy as np
from matplotlib.colors import to_rgba

# %%
viewer = napari.Viewer()
viewer.add_labels(np.load(r"bel_vascumap/Bead_dev5_Merged_vessel_mask_iso_550.npy"))
viewer.add_image(np.load(r"bel_vascumap/Bead_dev5_Merged_vessel_proba_iso_550.npy"))
# Out:
# <Image layer 'Image' at 0x26ff2ca5650>

# %%
viewer = napari.Viewer()
viewer.add_labels(np.load(r"./Akinola_20231130_23YO_CS_HMVEC_day 7_merged_upd_img4_d12_Merged_vessel_mask_iso_5588_cropped.npy"), name="Akinola", colormap={1: np.array(to_rgba("red"), dtype=float)})
viewer.add_labels(np.load(r"./20250619_Vascumap_Dev25_11_Wicell10_20250619_Vascumap_Dev25_11_Wicell10_vessel_mask_iso_9171_cropped.npy"), name="Dorota", colormap={1: np.array(to_rgba("darkorange"), dtype=float)})
viewer.add_labels(np.load(r"./Akinola_09102024_day7_hmvec_cs_merged_img2_vessels_only_v4_Merged_vessel_mask_iso_3006_cropped.npy"), name="Akinola", colormap={1: np.array(to_rgba("yellow"), dtype=float)})
viewer.add_labels(np.load(r"./20250619_Vascumap_Dev25_11_Tulip10_20250619_Vascumap_Dev25_11_Tulip10_vessel_mask_iso_235_cropped.npy"), name="Dorota", colormap={1: np.array(to_rgba("limegreen"), dtype=float)})
viewer.add_labels(np.load(r"./20250619_Vascumap_Dev25_11_WicellWicellECFB10_20250619_Vascumap_Dev25_11_WicellWicellECFB10_vessel_mask_iso_1547_cropped.npy"), name="Dorota", colormap={1: np.array(to_rgba("dodgerblue"), dtype=float)})
viewer.add_labels(np.load(r"./Bead_dev5_Merged_vessel_mask_iso_550_cropped.npy"), name="Marina", colormap={1: np.array(to_rgba("darkviolet"), dtype=float)})
viewer.add_labels(np.load(r"./Defne_placenta_270325_Dexa2_Device_10_vessel_mask_iso_2326_cropped.npy"), name="Defne", colormap={1: np.array(to_rgba("deeppink"), dtype=float)})
# Out:
# c:\Users\taylorhearn\AppData\Local\miniconda3\envs\vascumap\Lib\site-packages\napari\utils\colormaps\colormap.py:455: UserWarning: color_dict did not provide a default color. Missing keys will be transparent. To provide a default color, use the key `None`, or provide a defaultdict instance.
#   warn(
# c:\Users\taylorhearn\AppData\Local\miniconda3\envs\vascumap\Lib\site-packages\napari\utils\colormaps\colormap.py:455: UserWarning: color_dict did not provide a default color. Missing keys will be transparent. To provide a default color, use the key `None`, or provide a defaultdict instance.
#   warn(
# c:\Users\taylorhearn\AppData\Local\miniconda3\envs\vascumap\Lib\site-packages\napari\utils\colormaps\colormap.py:455: UserWarning: color_dict did not provide a default color. Missing keys will be transparent. To provide a default color, use the key `None`, or provide a defaultdict instance.
#   warn(
# ...
