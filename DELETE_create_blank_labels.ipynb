# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import os
import pandas as pd
from scipy import ndimage as ndi
from skimage.transform import rescale
from skimage.measure import marching_cubes, mesh_surface_area, label, regionprops, regionprops_table
from skimage import util, measure
import napari
from tifffile import imread
from liffile import LifFile
from pathlib import Path
import imagej
from imagej import Mode
import scyjava as sj
from matplotlib.colors import to_rgba
import tifffile as tiff

# import warnings
# warnings.filterwarnings("ignore")

# %%
def step(axis, xa):
    if axis not in xa.coords or xa.coords[axis].size < 2:
        return None
    return float(xa.coords[axis][1] - xa.coords[axis][0])

# %%
folder = Path(r"Z:\Bel\Vascumap_Example_Lifs\done\marina")
tif_files = list(folder.glob("*.tif"))
output_dir = r"Z:\Bel\Vascumap_Example_Lifs\max_projections\unseen_images"
for i, tif_path in enumerate(tif_files):
    tif_name = "".join(os.path.basename(tif_path).lower().replace(".tif", "")).replace(".", "_")
    print(tif_name)
    all_outputs = []

    try:      
        img = imread(tif_path)
        print(img.shape)

        # Extract metadata from the TIFF file
        with tiff.TiffFile(tif_path) as tif:
            metadata = tif.pages[0].tags
            x_resolution = metadata['XResolution'].value if 'XResolution' in metadata else None
            y_resolution = metadata['YResolution'].value if 'YResolution' in metadata else None

        if x_resolution and y_resolution:
            x_um = 1 / x_resolution[0] * x_resolution[1] * 1e6  # Convert to micrometers
            y_um = 1 / y_resolution[0] * y_resolution[1] * 1e6  # Convert to micrometers
        else:
            x_um = y_um = None

        print(f"Pixel size: {x_um} µm x {y_um} µm")

        max_proj = np.max(img, axis=0)  # Z projection
        z_proj = np.max(img, axis=1)  # Y projection

        out_path_max = os.path.join(
            output_dir,
            f"{tif_name}_img{i}_maxproj.ome.tif"
        )
        out_path_z = os.path.join(
            output_dir,
            f"{tif_name}_img{i}_zproj.ome.tif"
        )

        tiff.imwrite(
            out_path_max,
            max_proj.astype(np.float32),
            ome=True,
            metadata={
                "PhysicalSizeX": x_um,
                "PhysicalSizeY": y_um,
                "PhysicalSizeXUnit": "µm",
                "PhysicalSizeYUnit": "µm",
            }
        )

    except Exception as e:
        print(f"Could not process image {i} in {tif_name}: {e}")

# %%
folder = Path(r"Z:\Bel\Vascumap_Example_Lifs\done\marina")
lif_files = list(folder.glob("*.lif"))
output_dir = r"Z:\Bel\Vascumap_Example_Lifs\max_projections\unseen_images"
for lif_path in lif_files:
    lif_name = "".join(os.path.basename(lif_path).lower().replace(".lif", "")).replace(".", "_")
    print(lif_name)
    all_outputs = []
    with LifFile(lif_path) as lif:
        number_of_lifs = len(lif.images)

        for i in range(number_of_lifs):
            print("{}, {}".format(i, lif_name))   
            try:      
                img = lif.images[i]
                print(img.dims)
                if img.dims == ('C', 'Z', 'Y', 'X'):
                    print("image shape is {}".format(img.shape))
                    image = img.asarray()
                    image = image[0, :, :, :]  # Take first channel
                    print("image shape is {}".format(image.shape))

                    max_proj = np.max(image, axis=0)
                    xa = img.asxarray()

                    # liffile coordinates are typically in meters → convert to µm
                    x_um = step("X", xa) * 1e6 if step("X", xa) is not None else None
                    print(f"step size um {x_um}")
                    out_path = os.path.join(
                        output_dir,
                        f"{lif_name}_img{i}_maxproj.ome.tif"
                    )

                    tiff.imwrite(
                        out_path,
                        max_proj.astype(np.float32),
                        ome=True,
                        metadata={
                            "PhysicalSizeX": x_um,
                            "PhysicalSizeY": x_um,
                            "PhysicalSizeXUnit": "µm",
                            "PhysicalSizeYUnit": "µm",
                        }
                    )
                if img.dims == ('Z', 'Y', 'X'):
                    image = img.asarray()

                    max_proj = np.max(image, axis=0)
                    xa = img.asxarray()

                    # liffile coordinates are typically in meters → convert to µm
                    x_um = step("X", xa) * 1e6 if step("X", xa) is not None else None
                    print(f"step size um {x_um}")
                    out_path = os.path.join(
                        output_dir,
                        f"{lif_name}_img{i}_maxproj.ome.tif"
                    )

                    tiff.imwrite(
                        out_path,
                        max_proj.astype(np.float32),
                        ome=True,
                        metadata={
                            "PhysicalSizeX": x_um,
                            "PhysicalSizeY": x_um,
                            "PhysicalSizeXUnit": "µm",
                            "PhysicalSizeYUnit": "µm",
                        }
                    )
            except:
                print(f"Could not process image {i} in {lif_name}")
# Out:
# marina_m4_2024_10_24_fl2_fl6
# 0, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 1, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 3, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 4, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 5, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 6, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 7, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 9, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 10, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 11, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 13, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 15, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 16, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 17, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 18, marina_m4_2024_10_24_fl2_fl6
# ('M', 'Z', 'Y', 'X')
# 19, marina_m4_2024_10_24_fl2_fl6
# ('M', 'Z', 'Y', 'X')
# 20, marina_m4_2024_10_24_fl2_fl6
# ('M', 'Z', 'Y', 'X')
# 21, marina_m4_2024_10_24_fl2_fl6
# ('M', 'Z', 'Y', 'X')
# 22, marina_m4_2024_10_24_fl2_fl6
# ('M', 'Z', 'Y', 'X')
# 23, marina_m4_2024_10_24_fl2_fl6
# ('M', 'Z', 'Y', 'X')
# 24, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 25, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# 26, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 27, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 28, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 29, marina_m4_2024_10_24_fl2_fl6
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m4_2024_11_14_mcl1_mcl3
# 0, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 1, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 3, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 4, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 5, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 6, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 9, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 10, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 11, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 12, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 13, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 15, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 16, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 17, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 18, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 19, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 20, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 21, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# 22, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 23, marina_m4_2024_11_14_mcl1_mcl3
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m4_2024_12_04_fl4_fl12
# 0, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 1, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 3, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 4, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 5, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 6, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 9, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 10, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 11, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 13, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 15, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 16, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 17, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 18, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 19, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 20, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 21, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 22, marina_m4_2024_12_04_fl4_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m4_2025_02_05_mcl2_mcl4
# 0, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 1, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 3, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 4, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 5, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 6, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 9, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 10, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 11, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 13, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 15, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 16, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 17, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 18, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 19, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 20, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 21, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 22, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# 23, marina_m4_2025_02_05_mcl2_mcl4
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m4_2025_02_28_fl32_fl33
# 0, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 1, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 3, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 4, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 5, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 6, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 9, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 10, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 11, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 13, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 15, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 16, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 17, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 18, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 19, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 20, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 21, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 22, marina_m4_2025_02_28_fl32_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m4_2025_03_23_mcl7_mcl8
# 0, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 1, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 3, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 4, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 5, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 6, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 7, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 9, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 10, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 11, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 13, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 15, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 16, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 17, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 18, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 19, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 20, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 21, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 22, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# 23, marina_m4_2025_03_23_mcl7_mcl8
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m4_2025_06_27_fl41_fl43
# 0, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 1, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 3, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 4, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 5, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 6, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 9, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 10, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 11, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 13, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 15, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 16, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 17, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 18, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 19, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 20, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 21, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 22, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 23, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 24, marina_m4_2025_06_27_fl41_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# marina_m7_2025_10_06_fl33
# 0, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 1, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 2, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 3, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 4, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 5, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 6, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 8, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 9, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 10, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 11, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 13, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 14, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 15, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 16, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 17, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 18, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# 19, marina_m7_2025_10_06_fl33
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m7_2025_10_22_fl12
# 0, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 1, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 2, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 3, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 4, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 5, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 6, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 8, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 9, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 10, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 11, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 13, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 15, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 16, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 17, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 18, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 19, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 20, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 21, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 22, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 23, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# 24, marina_m7_2025_10_22_fl12
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m7_2025_11_12_fl43
# 0, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 1, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 2, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 3, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 4, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 5, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 6, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 9, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 10, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 11, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 12, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 13, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 15, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 16, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 17, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 18, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 19, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 20, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 21, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 22, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 23, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 24, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 25, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 26, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 27, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 28, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 29, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 30, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 31, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 32, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 33, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 34, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 35, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 36, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 37, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 38, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 39, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 40, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 41, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 42, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 43, marina_m7_2025_11_12_fl43
# ('M', 'Z', 'Y', 'X')
# 44, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 45, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 46, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# 47, marina_m7_2025_11_12_fl43
# ('Z', 'Y', 'X')
# step size um 1.3
# marina_m7_2025_12_05_fl39
# 0, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 1, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 2, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 3, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 4, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 5, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 6, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 7, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 8, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 9, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 10, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 11, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 12, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 13, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 14, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 15, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 16, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 17, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 18, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.2999999999999998
# 19, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 20, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 21, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 22, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3
# 23, marina_m7_2025_12_05_fl39
# ('Z', 'Y', 'X')
# step size um 1.3

# %%
from pathlib import Path
import numpy as np
import tifffile as tiff
from skimage.transform import downscale_local_mean

in_dir = Path(r"Z:\Bel\Vascumap_Example_Lifs\max_projections\unseen_images\next_batch")
out_root = in_dir / "downsampled4"
img_out = out_root / "images"
lab_out = out_root / "labels"
img_out.mkdir(parents=True, exist_ok=True)
lab_out.mkdir(parents=True, exist_ok=True)

DS = 4  # integer downsample factor

tif_paths = sorted(list(in_dir.glob("*.tif")) + list(in_dir.glob("*.tiff")))

for p in tif_paths:
    try:
        im = tiff.imread(p)

        if im.ndim != 2:
            raise ValueError(f"{p.name}: expected 2D, got shape {im.shape}")

        h, w = im.shape
        # crop so dimensions are divisible by DS (required for downscale_local_mean)
        h2, w2 = (h // DS) * DS, (w // DS) * DS
        im_c = im[:h2, :w2]

        im_ds = downscale_local_mean(im_c, (DS, DS))

        # cast back to original dtype if you want (common: uint16)
        if np.issubdtype(im.dtype, np.integer):
            im_ds = np.clip(np.rint(im_ds), 0, np.iinfo(im.dtype).max).astype(im.dtype)
        else:
            im_ds = im_ds.astype(np.float32)

        out_img_path = img_out / p.name
        tiff.imwrite(out_img_path, im_ds)

        lab = np.zeros(im_ds.shape, dtype=np.uint8)
        out_lab_path = lab_out / f"{p.stem}_labels.tif"
        tiff.imwrite(out_lab_path, lab)
    except Exception as e:
        print(f"Could not process image {p.name}: {e}")

print(f"Processed {len(tif_paths)} images")
print(f"Downsampled images: {img_out}")
print(f"Blank labels:       {lab_out}")
# Out:
# Processed 0 images
# Downsampled images: Z:\Bel\Vascumap_Example_Lifs\max_projections\labelled_images\downsampled4\images
# Blank labels:       Z:\Bel\Vascumap_Example_Lifs\max_projections\labelled_images\downsampled4\labels
